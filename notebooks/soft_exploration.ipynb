# %%
import pandas as pd

# Load the main SOFT dataset (tab-separated)
df = pd.read_csv("../soft/dataset/ACLARC_SOFT.tsv", sep="\t")

# How big is it, and what are the columns?
print("Shape:", df.shape)
print("\nColumns:", list(df.columns))
print("\nFirst few rows:")
df.head()
# Out:
# Shape: (1931, 11)
#
# Columns: ['unique_id', 'citing_ACL_id', 'cite_context_paragraph', 'citation_object', 'citation_function', 'aclarc_label', 'citing_title', 'cited_title', 'cited_authors', 'section_title', 'citation_context']
#
# First few rows:
#   unique_id citing_ACL_id                             cite_context_paragraph  \
# 0       CC1      A00-1009  ['The framework represents a generalization of...
# 1      CC10      A00-1020  ['Currently, some of the best-performing and m...
# 2     CC100      D10-1101  ['Our results also confirm the insights gained...
# 3    CC1000      P00-1012  ['The simplest strategy for ordering adjective...
# 4    CC1001      P00-1012  ['The second area where the methods described ...
#
#      citation_object      citation_function        aclarc_label  \
# 0     Performed Work          Contextualize          BACKGROUND
# 1  Produced Resource                    Use                USES
# 2          Discovery  Justify Design Choice  COMPARES_CONTRASTS
# ...

# %%
# See the actual label values in each label-related column
print("citation_function (intent?) values:")
print(df['citation_function'].value_counts())

print("\ncitation_object (content?) values:")
print(df['citation_object'].value_counts())

print("\naclarc_label values:")
print(df['aclarc_label'].value_counts())
# Out:
# citation_function (intent?) values:
# citation_function
# Contextualize            1153
# Use                       351
# Justify Design Choice     156
# Signal Gap                 90
# Highlight Limitation       90
# Evaluate Against           72
# Modify                     19
# Name: count, dtype: int64
#
# citation_object (content?) values:
# citation_object
# Produced Resource    1006
# Performed Work        478
# Discovery             447
# Name: count, dtype: int64
#
# aclarc_label values:
# aclarc_label
# BACKGROUND            992
# USES                  360
# COMPARES_CONTRASTS    350
# MOTIVATION             88
# EXTENSION              72
# FUTURE                 69
# Name: count, dtype: int64
